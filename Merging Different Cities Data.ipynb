# %%
import pandas as pd
import numpy as np

# %%
ahd_df = pd.read_csv('Ahmedabad Rental Data')
bglr_df = pd.read_csv('Bangalore Rental Data')
clt_df = pd.read_csv('Calcutta Rental Data')
delhi_df = pd.read_csv('Delhi Rental Data')
hyd_df = pd.read_csv('Hyderabad Rental Data')
mad_df = pd.read_csv('Madras Rental Data')

# %% [markdown]
# #### Deletion of Unnamed columns

# %%
del ahd_df['Unnamed: 0']

# %%
ahd_df.head()
# Out:
#     House Type             Location      Price Built up Area  \
# 0   5 BHK Flat                Shela  ₹1,00,000    4700 sq.ft
# 1  4 BHK Villa  Vaishno Devi Circle    ₹60,000    7990 sq.ft
# 2   3 BHK Flat               Shilaj    ₹30,000    1750 sq.ft
# 3   3 BHK Flat           Shantigram    ₹40,000    1850 sq.ft
# 4   3 BHK Flat  Vaishno Devi Circle    ₹46,000    1080 sq.ft
#
#   Furnishing Status                                Highlights/Insights  \
# 0    Semi furnished  ['Close to Jain Temple', 'Marble', 'Landscaped...
# 1   Fully furnished             ['Amenities: Parking', 'Gas Pipeline']
# 2      Un-furnished  ['Children Play Area', 'Landscaped Garden', "K...
# 3    Semi furnished  ['24x7 Security', 'Business Center', 'Close to...
# 4   Fully furnished                             ['Amenities: Parking']
#
#                     Agent Name Verification Status No. of customer Contacted
# 0                 Preet Gandhi            Verified                      500+
# ...

# %%
del bglr_df['Unnamed: 0']

# %%
bglr_df.head()
# Out:
#                         House Type     Location    Price Built up Area  \
# 0          2 BHK Independent House     Hulimavu  ₹22,000    1200 sq.ft
# 1                       2 BHK Flat   Carmelaram  ₹43,000     900 sq.ft
# 2                       1 BHK Flat   BTM Layout  ₹16,000     650 sq.ft
# 3  2 BHK Independent Builder Floor  Singasandra  ₹35,000    1100 sq.ft
# 4  2 BHK Independent Builder Floor     Cox Town  ₹30,000    1100 sq.ft
#
#   Furnishing Status                                Highlights/Insights  \
# 0    Semi furnished  ['24x7 Security', 'Close to Mall', 'Close to M...
# 1    Semi furnished  ['Close to Bus Stop', 'Close to Grocery Stores...
# 2    Semi furnished  ['Close to ATM', 'Close to Bus Stop', 'Close t...
# 3    Semi furnished  ['24x7 Security', 'Close to Bus Stop', 'Close ...
# 4    Semi furnished  ['Security Guards', 'Service Lift', 'Sewage Tr...
#
#         Agent Name Verification Status No. of customer Contacted
# ...

# %%
#del clt_df['Unnamed: 0']

# %%
clt_df.head()
# Out:
#    House Type     Location      Price Built up Area Furnishing Status  \
# 0  4 BHK Flat  Ashok Nagar  ₹1,00,000    2114 sq.ft    Semi furnished
# 1  2 BHK Flat     Kaikhali    ₹15,000    1108 sq.ft    Semi furnished
# 2  4 BHK Flat     New Town    ₹70,000    1650 sq.ft      Un-furnished
# 3  2 BHK Flat     New Town    ₹22,000     680 sq.ft   Fully furnished
# 4  2 BHK Flat    Keshtopur    ₹13,000    1100 sq.ft      Un-furnished
#
#                                  Highlights/Insights  \
# 0  ['Gated Community', 'Good Cross Ventilation', ...
# 1                             ['Amenities: Parking']
# 2  ['24x7 Security', 'Gymnasium', 'Swimming Pool'...
# 3                        ['Amenities: Gas Pipeline']
# 4  ['Lift', 'Marble', 'Closer to Pharmacy', 'Clos...
#
#                     Agent Name Verification Status No. of customer Contacted
# 0            Secure Properties        Verified,New                      400+
# ...

# %%
del delhi_df['Unnamed: 0']

# %%
delhi_df.head()
# Out:
#                         House Type          Location    Price Built up Area  \
# 0                       3 BHK Flat   Sector 4 Dwarka  ₹44,000    1700 sq.ft
# 1                       3 BHK Flat  Sector 24 Dwarka  ₹50,000    2100 sq.ft
# 2  2 BHK Independent Builder Floor     Malviya Nagar  ₹43,000    1200 sq.ft
# 3  2 BHK Independent Builder Floor           Kalkaji  ₹43,000    1200 sq.ft
# 4                       1 BHK Flat     Said-Ul-Ajaib  ₹16,000     900 sq.ft
#
#   Furnishing Status                                Highlights/Insights  \
# 0    Semi furnished  ['Lift', 'Gated Community', 'Power Backup', '2...
# 1    Semi furnished    ['Amenities: Gym', 'Lift', 'Parking', 'Garden']
# 2   Fully furnished  ['ATM', '24x7 Security', 'Children Play Area',...
# 3   Fully furnished  ['24x7 Security', 'Gated Community', 'Close to...
# 4    Semi furnished  ['24x7 Security', 'Utility Shops', 'Metro Stat...
#
#                              Agent Name Verification Status  \
# ...

# %%
del hyd_df['Unnamed: 0']

# %%
hyd_df.head()
# Out:
#     House Type            Location    Price Built up Area Furnishing Status  \
# 0   3 BHK Flat            Narsingi  ₹67,000    2020 sq.ft    Semi furnished
# 1   1 BHK Flat            Madhapur  ₹30,000     650 sq.ft   Fully furnished
# 2  4 BHK Villa              Mokila  ₹66,000    3900 sq.ft    Semi furnished
# 3   2 BHK Flat  Financial District  ₹64,000    1027 sq.ft   Fully furnished
# 4   3 BHK Flat            Madhapur  ₹50,000    2200 sq.ft   Fully furnished
#
#                                  Highlights/Insights        Agent Name  \
# 0  ['24x7 Security', 'Basketball Court', 'Busines...  Datrika Srinivas
# 1  ['Close to ATM', 'Close to Bus Stop', 'Close t...  Mudavath Pushkar
# 2  ['24 Hours Concierge', '24x7 Security', 'ATM',...      Venkat Patel
# 3  ['Tennis Court', 'Swimming Pool', 'Basketball ...        Propertify
# 4  ['Amenities: Lift', 'Parking', 'Power Backup',...      Srinunayak10
#
#   Verification Status No. of customer Contacted
# ...

# %%
del mad_df['Unnamed: 0']

# %%
mad_df.head()
# Out:
#                 House Type      Location      Price Built up Area  \
# 0               4 BHK Flat  Besant Nagar  ₹1,75,000    2700 sq.ft
# 1               3 BHK Flat   Gopalapuram  ₹1,00,000    2300 sq.ft
# 2               3 BHK Flat  Thoraipakkam    ₹90,000    2031 sq.ft
# 3  5 BHK Independent House      Panaiyur  ₹1,75,000    6000 sq.ft
# 4               2 BHK Flat       Egattur    ₹25,000     700 sq.ft
#
#   Furnishing Status                                Highlights/Insights  \
# 0    Semi furnished  ['Close to Grocery Stores', 'Close to Hospital...
# 1    Semi furnished  ['Gymnasium', '24x7 Security', 'School Proximi...
# 2    Semi furnished  ['Power Backup', 'Swimming Pool', 'Gymnasium',...
# 3    Semi furnished  ['24x7 Security', 'Good Cross Ventilation', 'L...
# 4    Semi furnished  ['Amenities: Pool', 'Gym', 'Lift', 'Power Back...
#
#           Agent Name Verification Status No. of customer Contacted
# 0     KS PROP REALTY                 NaN                      500+
# ...

# %% [markdown]
# #### Merging

# %%
combine_df = pd.concat([ahd_df,bglr_df,clt_df,delhi_df,hyd_df,mad_df], axis = 0, ignore_index=True)

# %%
combine_df
# Out:
#                    House Type              Location      Price Built up Area  \
# 0                  5 BHK Flat                 Shela  ₹1,00,000    4700 sq.ft
# 1                 4 BHK Villa   Vaishno Devi Circle    ₹60,000    7990 sq.ft
# 2                  3 BHK Flat                Shilaj    ₹30,000    1750 sq.ft
# 3                  3 BHK Flat            Shantigram    ₹40,000    1850 sq.ft
# 4                  3 BHK Flat   Vaishno Devi Circle    ₹46,000    1080 sq.ft
# ...                       ...                   ...        ...           ...
# 1945               3 BHK Flat             Perungudi    ₹60,000    1650 sq.ft
# 1946              3 BHK Villa        Sholinganallur    ₹90,000    1606 sq.ft
# 1947               4 BHK Flat  Raja Annamalai Puram  ₹4,00,000    3955 sq.ft
# 1948               2 BHK Flat        Sholinganallur    ₹28,000    1240 sq.ft
# 1949  3 BHK Independent House          Thoraipakkam    ₹30,000    2000 sq.ft
#
# ...

# %%
combine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1950 entries, 0 to 1949
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   House Type                 1950 non-null   object
#  1   Location                   1950 non-null   object
#  2   Price                      1950 non-null   object
#  3   Built up Area              1950 non-null   object
#  4   Furnishing Status          1950 non-null   object
#  5   Highlights/Insights        1950 non-null   object
#  6   Agent Name                 1950 non-null   object
#  7   Verification Status        1609 non-null   object
#  8   No. of customer Contacted  1748 non-null   object
# dtypes: object(9)
# memory usage: 137.2+ KB

# %%
combine_df.isnull().sum()/len(combine_df)
# Out:
# House Type                   0.000000
# Location                     0.000000
# Price                        0.000000
# Built up Area                0.000000
# Furnishing Status            0.000000
# Highlights/Insights          0.000000
# Agent Name                   0.000000
# Verification Status          0.174872
# No. of customer Contacted    0.103590
# dtype: float64

# %%
lst1 = [ahd_df,bglr_df,clt_df,delhi_df,hyd_df,mad_df]
sum = 0
for i in lst1:
    print(f'{len(i)}')
    sum += len(i)

print(sum,'----------')
# Out:
# 240
# 420
# 240
# 240
# 570
# 240
# 1950 ----------

# %%
combine_df.to_csv('Rental_dataset.csv')

# %%
ahd_df['City'] = 'Ahmedabad'
bglr_df['City'] = 'Bengaluru'
clt_df['City'] = 'Calcutta'
delhi_df['City'] = 'Delhi'
hyd_df['City'] = 'Hyderabad'
mad_df['City'] = 'Madras'

# %%
combine_df = pd.concat([ahd_df,bglr_df,clt_df,delhi_df,hyd_df,mad_df], axis = 0, ignore_index=True)

# %%
combine_df.to_csv('Rental_dataset.csv')

# %%
rental_data = pd.read_csv('Rental_dataset.csv')

# %%
rental_data
# Out:
#       Unnamed: 0               House Type              Location      Price  \
# 0              0               5 BHK Flat                 Shela  ₹1,00,000
# 1              1              4 BHK Villa   Vaishno Devi Circle    ₹60,000
# 2              2               3 BHK Flat                Shilaj    ₹30,000
# 3              3               3 BHK Flat            Shantigram    ₹40,000
# 4              4               3 BHK Flat   Vaishno Devi Circle    ₹46,000
# ...          ...                      ...                   ...        ...
# 1945        1945               3 BHK Flat             Perungudi    ₹60,000
# 1946        1946              3 BHK Villa        Sholinganallur    ₹90,000
# 1947        1947               4 BHK Flat  Raja Annamalai Puram  ₹4,00,000
# 1948        1948               2 BHK Flat        Sholinganallur    ₹28,000
# 1949        1949  3 BHK Independent House          Thoraipakkam    ₹30,000
#
#      Built up Area Furnishing Status  \
# ...
