# %%
import numpy as np
import pandas as pd
import re

# %%
rental_data = pd.read_csv('Rental_dataset.csv')

# %%
rental_data.head()
# Out:
#    Unnamed: 0   House Type             Location      Price Built up Area  \
# 0           0   5 BHK Flat                Shela  ₹1,00,000    4700 sq.ft
# 1           1  4 BHK Villa  Vaishno Devi Circle    ₹60,000    7990 sq.ft
# 2           2   3 BHK Flat               Shilaj    ₹30,000    1750 sq.ft
# 3           3   3 BHK Flat           Shantigram    ₹40,000    1850 sq.ft
# 4           4   3 BHK Flat  Vaishno Devi Circle    ₹46,000    1080 sq.ft
#
#   Furnishing Status                                Highlights/Insights  \
# 0    Semi furnished  ['Close to Jain Temple', 'Marble', 'Landscaped...
# 1   Fully furnished             ['Amenities: Parking', 'Gas Pipeline']
# 2      Un-furnished  ['Children Play Area', 'Landscaped Garden', "K...
# 3    Semi furnished  ['24x7 Security', 'Business Center', 'Close to...
# 4   Fully furnished                             ['Amenities: Parking']
#
#                     Agent Name Verification Status No. of customer Contacted  \
# ...

# %%
#### removing Un named columns

del rental_data['Unnamed: 0']

# %%
rental_data.head()
# Out:
#     House Type             Location      Price Built up Area  \
# 0   5 BHK Flat                Shela  ₹1,00,000    4700 sq.ft
# 1  4 BHK Villa  Vaishno Devi Circle    ₹60,000    7990 sq.ft
# 2   3 BHK Flat               Shilaj    ₹30,000    1750 sq.ft
# 3   3 BHK Flat           Shantigram    ₹40,000    1850 sq.ft
# 4   3 BHK Flat  Vaishno Devi Circle    ₹46,000    1080 sq.ft
#
#   Furnishing Status                                Highlights/Insights  \
# 0    Semi furnished  ['Close to Jain Temple', 'Marble', 'Landscaped...
# 1   Fully furnished             ['Amenities: Parking', 'Gas Pipeline']
# 2      Un-furnished  ['Children Play Area', 'Landscaped Garden', "K...
# 3    Semi furnished  ['24x7 Security', 'Business Center', 'Close to...
# 4   Fully furnished                             ['Amenities: Parking']
#
#                     Agent Name Verification Status No. of customer Contacted  \
# 0                 Preet Gandhi            Verified                      500+
# ...

# %% [markdown]
# ### Finding the missing Values:

# %%
rental_data.isnull().sum()
# Out:
# House Type                   0
# Location                     0
# Price                        0
# Built up Area                0
# Furnishing Status            0
# Highlights/Insights          0
# Agent Name                   0
# Verification Status          0
# No. of customer Contacted    0
# City                         0
# dtype: int64

# %%
rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1950 entries, 0 to 1949
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   House Type                 1950 non-null   object
#  1   Location                   1950 non-null   object
#  2   Price                      1950 non-null   object
#  3   Built up Area              1950 non-null   object
#  4   Furnishing Status          1950 non-null   object
#  5   Highlights/Insights        1950 non-null   object
#  6   Agent Name                 1950 non-null   object
#  7   Verification Status        1950 non-null   object
#  8   No. of customer Contacted  1950 non-null   object
#  9   City                       1950 non-null   object
# dtypes: object(10)
# memory usage: 152.5+ KB

# %%
print(rental_data['Verification Status'])
# Out:
# 0           Verified
# 1           Verified
# 2           Verified
# 3           Verified
# 4           Verified
#             ...
# 1945    Not Verified
# 1946    Not Verified
# 1947    Not Verified
# 1948    Not Verified
# 1949        Verified
# Name: Verification Status, Length: 1950, dtype: object

# %%
rental_data.tail(15)
# Out:
#                    House Type              Location      Price Built up Area  \
# 1935              3 BHK Villa           Injambakkam    ₹65,000    2400 sq.ft
# 1936  4 BHK Independent House            Palavakkam  ₹1,00,000    4200 sq.ft
# 1937               2 BHK Flat             Perungudi    ₹50,000    1200 sq.ft
# 1938  4 BHK Independent House               Uthandi  ₹1,25,000    4000 sq.ft
# 1939               4 BHK Flat            Karapakkam    ₹76,500    2344 sq.ft
# 1940  4 BHK Independent House               Uthandi  ₹1,00,000    4500 sq.ft
# 1941  1 BHK Independent House        Sholinganallur    ₹15,000     450 sq.ft
# 1942             3.5 BHK Flat              Mylapore  ₹1,00,000    2500 sq.ft
# 1943               3 BHK Flat             Perungudi  ₹1,30,000    1820 sq.ft
# 1944               4 BHK Flat  Raja Annamalai Puram  ₹4,00,000    3950 sq.ft
# 1945               3 BHK Flat             Perungudi    ₹60,000    1650 sq.ft
# ...

# %%
rental_data['Verification Status']
# Out:
# 0           Verified
# 1           Verified
# 2           Verified
# 3           Verified
# 4           Verified
#             ...
# 1945    Not Verified
# 1946    Not Verified
# 1947    Not Verified
# 1948    Not Verified
# 1949        Verified
# Name: Verification Status, Length: 1950, dtype: object

# %%
# Replacing null values in verification status into Non Verified.
rental_data['Verification Status'] = rental_data['Verification Status'].apply(lambda x : 'Not Verified' if pd.isnull(x) else x)

# %%
rental_data.tail(15)
# Out:
#                    House Type              Location      Price Built up Area  \
# 1935              3 BHK Villa           Injambakkam    ₹65,000    2400 sq.ft
# 1936  4 BHK Independent House            Palavakkam  ₹1,00,000    4200 sq.ft
# 1937               2 BHK Flat             Perungudi    ₹50,000    1200 sq.ft
# 1938  4 BHK Independent House               Uthandi  ₹1,25,000    4000 sq.ft
# 1939               4 BHK Flat            Karapakkam    ₹76,500    2344 sq.ft
# 1940  4 BHK Independent House               Uthandi  ₹1,00,000    4500 sq.ft
# 1941  1 BHK Independent House        Sholinganallur    ₹15,000     450 sq.ft
# 1942             3.5 BHK Flat              Mylapore  ₹1,00,000    2500 sq.ft
# 1943               3 BHK Flat             Perungudi  ₹1,30,000    1820 sq.ft
# 1944               4 BHK Flat  Raja Annamalai Puram  ₹4,00,000    3950 sq.ft
# 1945               3 BHK Flat             Perungudi    ₹60,000    1650 sq.ft
# ...

# %%
rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1950 entries, 0 to 1949
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   House Type                 1950 non-null   object
#  1   Location                   1950 non-null   object
#  2   Price                      1950 non-null   object
#  3   Built up Area              1950 non-null   object
#  4   Furnishing Status          1950 non-null   object
#  5   Highlights/Insights        1950 non-null   object
#  6   Agent Name                 1950 non-null   object
#  7   Verification Status        1950 non-null   object
#  8   No. of customer Contacted  1950 non-null   object
#  9   City                       1950 non-null   object
# dtypes: object(10)
# memory usage: 152.5+ KB

# %%
rental_data.isnull().sum()
# Out:
# House Type                   0
# Location                     0
# Price                        0
# Built up Area                0
# Furnishing Status            0
# Highlights/Insights          0
# Agent Name                   0
# Verification Status          0
# No. of customer Contacted    0
# City                         0
# dtype: int64

# %%
# Replacing Number of customer's contacted:

rental_data[rental_data['No. of customer Contacted'].isnull()]
# Out:
# Empty DataFrame
# Columns: [House Type, Location, Price, Built up Area, Furnishing Status, Highlights/Insights, Agent Name, Verification Status, No. of customer Contacted, City]
# Index: []

# %%
rental_data['No. of customer Contacted'] = rental_data['No. of customer Contacted'].apply(lambda x: 0 if pd.isnull(x) else x)

# %%
rental_data.head(15)
# Out:
#       House Type             Location      Price Built up Area  \
# 0     5 BHK Flat                Shela  ₹1,00,000    4700 sq.ft
# 1    4 BHK Villa  Vaishno Devi Circle    ₹60,000    7990 sq.ft
# 2     3 BHK Flat               Shilaj    ₹30,000    1750 sq.ft
# 3     3 BHK Flat           Shantigram    ₹40,000    1850 sq.ft
# 4     3 BHK Flat  Vaishno Devi Circle    ₹46,000    1080 sq.ft
# 5     3 BHK Flat               Zundal    ₹35,000    1500 sq.ft
# 6     3 BHK Flat                Bopal    ₹30,000    1100 sq.ft
# 7    4 BHK Villa           Shantipura    ₹35,000    1800 sq.ft
# 8   3.5 BHK Flat                Shela    ₹26,000    1510 sq.ft
# 9   1.5 BHK Flat             Vejalpur    ₹16,500     930 sq.ft
# 10    2 BHK Flat             Jagatpur    ₹28,000    1200 sq.ft
# 11    3 BHK Flat               Shilaj    ₹30,000    1760 sq.ft
# 12    3 BHK Flat                 Gota    ₹24,111    1899 sq.ft
# 13    2 BHK Flat  Vaishno Devi Circle    ₹22,000    1214 sq.ft
# ...

# %%
rental_data.isnull().sum()
# Out:
# House Type                   0
# Location                     0
# Price                        0
# Built up Area                0
# Furnishing Status            0
# Highlights/Insights          0
# Agent Name                   0
# Verification Status          0
# No. of customer Contacted    0
# City                         0
# dtype: int64

# %%
rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1950 entries, 0 to 1949
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   House Type                 1950 non-null   object
#  1   Location                   1950 non-null   object
#  2   Price                      1950 non-null   object
#  3   Built up Area              1950 non-null   object
#  4   Furnishing Status          1950 non-null   object
#  5   Highlights/Insights        1950 non-null   object
#  6   Agent Name                 1950 non-null   object
#  7   Verification Status        1950 non-null   object
#  8   No. of customer Contacted  1950 non-null   object
#  9   City                       1950 non-null   object
# dtypes: object(10)
# memory usage: 152.5+ KB

# %% [markdown]
# ### Removing Duplicate Values

# %%
rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1897 entries, 0 to 1949
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   House Type                 1897 non-null   object
#  1   Location                   1897 non-null   object
#  2   Price                      1897 non-null   object
#  3   Built up Area              1897 non-null   object
#  4   Furnishing Status          1897 non-null   object
#  5   Highlights/Insights        1897 non-null   object
#  6   Agent Name                 1897 non-null   object
#  7   Verification Status        1897 non-null   object
#  8   No. of customer Contacted  1897 non-null   object
#  9   City                       1897 non-null   object
# dtypes: object(10)
# memory usage: 163.0+ KB

# %%
rental_data.duplicated().sum()
# Out:
# 0

# %%
rental_data.shape
# Out:
# (1950, 10)

# %%
rental_data.drop_duplicates(keep = 'first' , inplace = True)

# %%
rental_data.duplicated().sum()
# Out:
# 0

# %%
rental_data.shape
# Out:
# (1897, 10)

# %%
rental_data
# Out:
#                    House Type              Location      Price Built up Area  \
# 0                  5 BHK Flat                 Shela  ₹1,00,000    4700 sq.ft
# 1                 4 BHK Villa   Vaishno Devi Circle    ₹60,000    7990 sq.ft
# 2                  3 BHK Flat                Shilaj    ₹30,000    1750 sq.ft
# 3                  3 BHK Flat            Shantigram    ₹40,000    1850 sq.ft
# 4                  3 BHK Flat   Vaishno Devi Circle    ₹46,000    1080 sq.ft
# ...                       ...                   ...        ...           ...
# 1945               3 BHK Flat             Perungudi    ₹60,000    1650 sq.ft
# 1946              3 BHK Villa        Sholinganallur    ₹90,000    1606 sq.ft
# 1947               4 BHK Flat  Raja Annamalai Puram  ₹4,00,000    3955 sq.ft
# 1948               2 BHK Flat        Sholinganallur    ₹28,000    1240 sq.ft
# 1949  3 BHK Independent House          Thoraipakkam    ₹30,000    2000 sq.ft
#
# ...

# %%
rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1897 entries, 0 to 1949
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   House Type                 1897 non-null   object
#  1   Location                   1897 non-null   object
#  2   Price                      1897 non-null   object
#  3   Built up Area              1897 non-null   object
#  4   Furnishing Status          1897 non-null   object
#  5   Highlights/Insights        1897 non-null   object
#  6   Agent Name                 1897 non-null   object
#  7   Verification Status        1897 non-null   object
#  8   No. of customer Contacted  1897 non-null   object
#  9   City                       1897 non-null   object
# dtypes: object(10)
# memory usage: 163.0+ KB

# %% [markdown]
# ### Converting Data Types:

# %%
rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1897 entries, 0 to 1949
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   House Type                 1897 non-null   object
#  1   Location                   1897 non-null   object
#  2   Price                      1897 non-null   object
#  3   Built up Area              1897 non-null   object
#  4   Furnishing Status          1897 non-null   object
#  5   Highlights/Insights        1897 non-null   object
#  6   Agent Name                 1897 non-null   object
#  7   Verification Status        1897 non-null   object
#  8   No. of customer Contacted  1897 non-null   object
#  9   City                       1897 non-null   object
# dtypes: object(10)
# memory usage: 163.0+ KB

# %%
# converting price into int:

rental_data.head()
# Out:
#     House Type             Location      Price Built up Area  \
# 0   5 BHK Flat                Shela  ₹1,00,000    4700 sq.ft
# 1  4 BHK Villa  Vaishno Devi Circle    ₹60,000    7990 sq.ft
# 2   3 BHK Flat               Shilaj    ₹30,000    1750 sq.ft
# 3   3 BHK Flat           Shantigram    ₹40,000    1850 sq.ft
# 4   3 BHK Flat  Vaishno Devi Circle    ₹46,000    1080 sq.ft
#
#   Furnishing Status                                Highlights/Insights  \
# 0    Semi furnished  ['Close to Jain Temple', 'Marble', 'Landscaped...
# 1   Fully furnished             ['Amenities: Parking', 'Gas Pipeline']
# 2      Un-furnished  ['Children Play Area', 'Landscaped Garden', "K...
# 3    Semi furnished  ['24x7 Security', 'Business Center', 'Close to...
# 4   Fully furnished                             ['Amenities: Parking']
#
#                     Agent Name Verification Status No. of customer Contacted  \
# 0                 Preet Gandhi            Verified                      500+
# ...

# %%
rental_data['Price'] = rental_data['Price'].str.replace('₹','')

# %%
rental_data.head()
# Out:
#     House Type             Location     Price Built up Area Furnishing Status  \
# 0   5 BHK Flat                Shela  1,00,000    4700 sq.ft    Semi furnished
# 1  4 BHK Villa  Vaishno Devi Circle    60,000    7990 sq.ft   Fully furnished
# 2   3 BHK Flat               Shilaj    30,000    1750 sq.ft      Un-furnished
# 3   3 BHK Flat           Shantigram    40,000    1850 sq.ft    Semi furnished
# 4   3 BHK Flat  Vaishno Devi Circle    46,000    1080 sq.ft   Fully furnished
#
#                                  Highlights/Insights  \
# 0  ['Close to Jain Temple', 'Marble', 'Landscaped...
# 1             ['Amenities: Parking', 'Gas Pipeline']
# 2  ['Children Play Area', 'Landscaped Garden', "K...
# 3  ['24x7 Security', 'Business Center', 'Close to...
# 4                             ['Amenities: Parking']
#
#                     Agent Name Verification Status No. of customer Contacted  \
# 0                 Preet Gandhi            Verified                      500+
# ...

# %%
rental_data['Price'] = rental_data['Price'].str.replace(',','')

# %%
rental_data.head()
# Out:
#     House Type             Location   Price Built up Area Furnishing Status  \
# 0   5 BHK Flat                Shela  100000    4700 sq.ft    Semi furnished
# 1  4 BHK Villa  Vaishno Devi Circle   60000    7990 sq.ft   Fully furnished
# 2   3 BHK Flat               Shilaj   30000    1750 sq.ft      Un-furnished
# 3   3 BHK Flat           Shantigram   40000    1850 sq.ft    Semi furnished
# 4   3 BHK Flat  Vaishno Devi Circle   46000    1080 sq.ft   Fully furnished
#
#                                  Highlights/Insights  \
# 0  ['Close to Jain Temple', 'Marble', 'Landscaped...
# 1             ['Amenities: Parking', 'Gas Pipeline']
# 2  ['Children Play Area', 'Landscaped Garden', "K...
# 3  ['24x7 Security', 'Business Center', 'Close to...
# 4                             ['Amenities: Parking']
#
#                     Agent Name Verification Status No. of customer Contacted  \
# 0                 Preet Gandhi            Verified                      500+
# ...

# %%
rental_data['Price'] = rental_data['Price'].astype(int)

# %%
rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1897 entries, 0 to 1949
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   House Type                 1897 non-null   object
#  1   Location                   1897 non-null   object
#  2   Price                      1897 non-null   int32
#  3   Built up Area              1897 non-null   object
#  4   Furnishing Status          1897 non-null   object
#  5   Highlights/Insights        1897 non-null   object
#  6   Agent Name                 1897 non-null   object
#  7   Verification Status        1897 non-null   object
#  8   No. of customer Contacted  1897 non-null   object
#  9   City                       1897 non-null   object
# dtypes: int32(1), object(9)
# memory usage: 155.6+ KB

# %%
#rental_data['Built up Area'] = rental_data['Built up Area in sq.f']

# %%
rental_data.rename(columns = {'Built up Area': 'Built up Area in sq.ft'}, inplace=True)

# %%
rental_data.head()
# Out:
#     House Type             Location   Price Built up Area in sq.ft  \
# 0   5 BHK Flat                Shela  100000             4700 sq.ft
# 1  4 BHK Villa  Vaishno Devi Circle   60000             7990 sq.ft
# 2   3 BHK Flat               Shilaj   30000             1750 sq.ft
# 3   3 BHK Flat           Shantigram   40000             1850 sq.ft
# 4   3 BHK Flat  Vaishno Devi Circle   46000             1080 sq.ft
#
#   Furnishing Status                                Highlights/Insights  \
# 0    Semi furnished  ['Close to Jain Temple', 'Marble', 'Landscaped...
# 1   Fully furnished             ['Amenities: Parking', 'Gas Pipeline']
# 2      Un-furnished  ['Children Play Area', 'Landscaped Garden', "K...
# 3    Semi furnished  ['24x7 Security', 'Business Center', 'Close to...
# 4   Fully furnished                             ['Amenities: Parking']
#
#                     Agent Name Verification Status No. of customer Contacted  \
# ...

# %%
rental_data['Built up Area in sq.ft'] = rental_data['Built up Area in sq.ft'].str.replace('sq.ft','')

# %%
rental_data.head()
# Out:
#     House Type             Location   Price Built up Area in sq.ft  \
# 0   5 BHK Flat                Shela  100000                  4700
# 1  4 BHK Villa  Vaishno Devi Circle   60000                  7990
# 2   3 BHK Flat               Shilaj   30000                  1750
# 3   3 BHK Flat           Shantigram   40000                  1850
# 4   3 BHK Flat  Vaishno Devi Circle   46000                  1080
#
#   Furnishing Status                                Highlights/Insights  \
# 0    Semi furnished  ['Close to Jain Temple', 'Marble', 'Landscaped...
# 1   Fully furnished             ['Amenities: Parking', 'Gas Pipeline']
# 2      Un-furnished  ['Children Play Area', 'Landscaped Garden', "K...
# 3    Semi furnished  ['24x7 Security', 'Business Center', 'Close to...
# 4   Fully furnished                             ['Amenities: Parking']
#
#                     Agent Name Verification Status No. of customer Contacted  \
# ...

# %%
rental_data['Built up Area in sq.ft'].apply(lambda x : x.strip())
# Out:
# 0       4700
# 1       7990
# 2       1750
# 3       1850
# 4       1080
#         ...
# 1945    1650
# 1946    1606
# 1947    3955
# 1948    1240
# 1949    2000
# Name: Built up Area in sq.ft, Length: 1897, dtype: object

# %%
rental_data.head()
# Out:
#     House Type             Location   Price Built up Area in sq.ft  \
# 0   5 BHK Flat                Shela  100000                  4700
# 1  4 BHK Villa  Vaishno Devi Circle   60000                  7990
# 2   3 BHK Flat               Shilaj   30000                  1750
# 3   3 BHK Flat           Shantigram   40000                  1850
# 4   3 BHK Flat  Vaishno Devi Circle   46000                  1080
#
#   Furnishing Status                                Highlights/Insights  \
# 0    Semi furnished  ['Close to Jain Temple', 'Marble', 'Landscaped...
# 1   Fully furnished             ['Amenities: Parking', 'Gas Pipeline']
# 2      Un-furnished  ['Children Play Area', 'Landscaped Garden', "K...
# 3    Semi furnished  ['24x7 Security', 'Business Center', 'Close to...
# 4   Fully furnished                             ['Amenities: Parking']
#
#                     Agent Name Verification Status No. of customer Contacted  \
# ...

# %%
rental_data['Built up Area in sq.ft'] = rental_data['Built up Area in sq.ft'].astype(float)

# %%
rental_data.head()
# Out:
#     House Type             Location   Price  Built up Area in sq.ft  \
# 0   5 BHK Flat                Shela  100000                  4700.0
# 1  4 BHK Villa  Vaishno Devi Circle   60000                  7990.0
# 2   3 BHK Flat               Shilaj   30000                  1750.0
# 3   3 BHK Flat           Shantigram   40000                  1850.0
# 4   3 BHK Flat  Vaishno Devi Circle   46000                  1080.0
#
#   Furnishing Status                                Highlights/Insights  \
# 0    Semi furnished  ['Close to Jain Temple', 'Marble', 'Landscaped...
# 1   Fully furnished             ['Amenities: Parking', 'Gas Pipeline']
# 2      Un-furnished  ['Children Play Area', 'Landscaped Garden', "K...
# 3    Semi furnished  ['24x7 Security', 'Business Center', 'Close to...
# 4   Fully furnished                             ['Amenities: Parking']
#
#                     Agent Name Verification Status No. of customer Contacted  \
# ...

# %%
rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1897 entries, 0 to 1949
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   House Type                 1897 non-null   object
#  1   Location                   1897 non-null   object
#  2   Price                      1897 non-null   int32
#  3   Built up Area in sq.ft     1897 non-null   float64
#  4   Furnishing Status          1897 non-null   object
#  5   Highlights/Insights        1897 non-null   object
#  6   Agent Name                 1897 non-null   object
#  7   Verification Status        1897 non-null   object
#  8   No. of customer Contacted  1897 non-null   object
#  9   City                       1897 non-null   object
# dtypes: float64(1), int32(1), object(8)
# memory usage: 155.6+ KB

# %%
rental_data['Verification Status'].unique()
# Out:
# array(['Verified', 'Verified,New', 'New', 'Not Verified',
#        'NewNo Brokerage'], dtype=object)

# %%
# Making values as equal in verifications status

# %%
rental_data[rental_data['Verification Status'] == 'NewNo Brokerage']
# Out:
#                           House Type     Location  Price  \
# 668                       3 BHK Flat     Rajarhat  20000
# 669  2 BHK Independent Builder Floor  Ashok Nagar  12000
#
#      Built up Area in sq.ft Furnishing Status  \
# 668                  1300.0      Un-furnished
# 669                   680.0    Semi furnished
#
#                                    Highlights/Insights  Agent Name  \
# 668      ['Amenities: Pool', 'Gym', 'Lift', 'Parking']  Soumen Das
# 669  ['Amenities: Parking', 'Intercom', 'Pet Allowe...  Pew Mondal
#
#     Verification Status No. of customer Contacted      City
# 668     NewNo Brokerage                         0  Calcutta
# 669     NewNo Brokerage                         0  Calcutta

# %%
rental_data['Verification Status'] = rental_data['Verification Status'].apply(lambda x: 'New' if x == 'NewNo Brokerage' else x)

# %%
rental_data['Verification Status'].unique()
# Out:
# array(['Verified', 'Verified,New', 'New', 'Not Verified'], dtype=object)

# %%
rental_data.loc[667:670]
# Out:
#                           House Type     Location  Price  \
# 667                       3 BHK Flat     New Town  31000
# 668                       3 BHK Flat     Rajarhat  20000
# 669  2 BHK Independent Builder Floor  Ashok Nagar  12000
# 670                       3 BHK Flat     New Town  35000
#
#      Built up Area in sq.ft Furnishing Status  \
# 667                  1250.0   Fully furnished
# 668                  1300.0      Un-furnished
# 669                   680.0    Semi furnished
# 670                  1370.0    Semi furnished
#
#                                    Highlights/Insights         Agent Name  \
# 667  ['24x7 Security', 'Close to Mall', 'School Pro...     Sudipta Sarkar
# 668      ['Amenities: Pool', 'Gym', 'Lift', 'Parking']         Soumen Das
# 669  ['Amenities: Parking', 'Intercom', 'Pet Allowe...         Pew Mondal
# 670  ['Indoor Game Room', 'Football Field', 'Gymnas...  LANDMARK REALTORS
#
#     Verification Status No. of customer Contacted      City
# ...

# %%
rental_data.tail()
# Out:
#                    House Type              Location   Price  \
# 1945               3 BHK Flat             Perungudi   60000
# 1946              3 BHK Villa        Sholinganallur   90000
# 1947               4 BHK Flat  Raja Annamalai Puram  400000
# 1948               2 BHK Flat        Sholinganallur   28000
# 1949  3 BHK Independent House          Thoraipakkam   30000
#
#       Built up Area in sq.ft Furnishing Status  \
# 1945                  1650.0    Semi furnished
# 1946                  1606.0    Semi furnished
# 1947                  3955.0    Semi furnished
# 1948                  1240.0    Semi furnished
# 1949                  2000.0      Un-furnished
#
#                                     Highlights/Insights  \
# 1945  ['24x7 Security', 'ATM', 'Close to Airport', '...
# 1946  ['24x7 Security', 'Gated Community', 'Communit...
# 1947  ['Lift', 'Rainwater Harvesting', 'Power Backup...
# 1948  ['24x7 Security', 'Gated Community', 'Communit...
# ...

# %%
# Cheking values in furnishing  status

# %%
rental_data['Furnishing Status'].unique()
# Out:
# array(['Semi furnished', 'Fully furnished', 'Un-furnished'], dtype=object)

# %%
rental_data['Verification Status'].unique()
# Out:
# array(['Verified', 'Verified,New', 'New', 'Not Verified'], dtype=object)

# %%
# adjucting index numbers,

# %%
rental_data.reset_index(drop = True, inplace = True)

# %%
rental_data.head()
# Out:
#     House Type             Location   Price  Built up Area in sq.ft  \
# 0   5 BHK Flat                Shela  100000                  4700.0
# 1  4 BHK Villa  Vaishno Devi Circle   60000                  7990.0
# 2   3 BHK Flat               Shilaj   30000                  1750.0
# 3   3 BHK Flat           Shantigram   40000                  1850.0
# 4   3 BHK Flat  Vaishno Devi Circle   46000                  1080.0
#
#   Furnishing Status                                Highlights/Insights  \
# 0    Semi furnished  ['Close to Jain Temple', 'Marble', 'Landscaped...
# 1   Fully furnished             ['Amenities: Parking', 'Gas Pipeline']
# 2      Un-furnished  ['Children Play Area', 'Landscaped Garden', "K...
# 3    Semi furnished  ['24x7 Security', 'Business Center', 'Close to...
# 4   Fully furnished                             ['Amenities: Parking']
#
#                     Agent Name Verification Status No. of customer Contacted  \
# ...

# %%
rental_data['No. of customer Contacted'] = rental_data['No. of customer Contacted'].str.replace('+','').astype(float)

# %%
rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1897 entries, 0 to 1896
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   House Type                 1897 non-null   object
#  1   Location                   1897 non-null   object
#  2   Price                      1897 non-null   int32
#  3   Built up Area in sq.ft     1897 non-null   float64
#  4   Furnishing Status          1897 non-null   object
#  5   Highlights/Insights        1897 non-null   object
#  6   Agent Name                 1897 non-null   object
#  7   Verification Status        1897 non-null   object
#  8   No. of customer Contacted  1715 non-null   float64
#  9   City                       1897 non-null   object
# dtypes: float64(2), int32(1), object(7)
# memory usage: 140.9+ KB

# %%
rental_data.to_csv('Cleaned Rental Data.csv',index=False)

# %%
cleaned_df = pd.read_csv('Cleaned Rental Data.csv')

# %%
cleaned_df
# Out:
#                    House Type              Location   Price  \
# 0                  5 BHK Flat                 Shela  100000
# 1                 4 BHK Villa   Vaishno Devi Circle   60000
# 2                  3 BHK Flat                Shilaj   30000
# 3                  3 BHK Flat            Shantigram   40000
# 4                  3 BHK Flat   Vaishno Devi Circle   46000
# ...                       ...                   ...     ...
# 1892               3 BHK Flat             Perungudi   60000
# 1893              3 BHK Villa        Sholinganallur   90000
# 1894               4 BHK Flat  Raja Annamalai Puram  400000
# 1895               2 BHK Flat        Sholinganallur   28000
# 1896  3 BHK Independent House          Thoraipakkam   30000
#
#       Built up Area in sq.ft Furnishing Status  \
# 0                     4700.0    Semi furnished
# 1                     7990.0   Fully furnished
# 2                     1750.0      Un-furnished
# 3                     1850.0    Semi furnished
# ...

# %%
cleaned_df.columns
# Out:
# Index(['House Type', 'Location', 'Price', 'Built up Area in sq.ft',
#        'Furnishing Status', 'Highlights/Insights', 'Agent Name',
#        'Verification Status', 'No. of customer Contacted', 'City'],
#       dtype='object')

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1897 entries, 0 to 1896
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   House Type                 1897 non-null   object
#  1   Location                   1897 non-null   object
#  2   Price                      1897 non-null   int64
#  3   Built up Area in sq.ft     1897 non-null   float64
#  4   Furnishing Status          1897 non-null   object
#  5   Highlights/Insights        1897 non-null   object
#  6   Agent Name                 1897 non-null   object
#  7   Verification Status        1897 non-null   object
#  8   No. of customer Contacted  1715 non-null   float64
#  9   City                       1897 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 148.3+ KB
